# %%
from delta import configure_spark_with_delta_pip
import pyspark
import requests
import pandas as pd
import json
import csv

# %%
with open("credentials.txt", "r") as f:
    api_key = f.read()

headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': api_key,
}

# API endpoint
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'

# Making API request
r = requests.get(url, headers=headers)
data = r.json()
# print(data)
transformed_data_list = []

for currency in data['data']:
    transformed_data = {
        'id': int(currency["id"]),  
        'name': currency["name"],
        'symbol': currency["symbol"],
        'date_added': currency["date_added"],
        "Price": float(currency['quote']['USD']['price']), 
        'volume_24h': float(currency['quote']['USD']['volume_24h']),
        'volume_change_24h': float(currency['quote']['USD']['volume_change_24h']),
        'max_supply': float(currency["max_supply"]) if currency["max_supply"] is not None else None,
        'circulating_supply': float(currency["circulating_supply"]) if currency["circulating_supply"] is not None else None,
        'total_supply': float(currency["total_supply"]) if currency["total_supply"] is not None else None,
        'infinite_supply': str(currency["infinite_supply"]),  
        'cmc_rank': int(currency["cmc_rank"]),  
        'last_updated': currency["last_updated"]
    }
    
    transformed_data_list.append(transformed_data)
transformed_data_list
# Out:
# [{'id': 1,
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'date_added': '2010-07-13T00:00:00.000Z',
#   'Price': 84644.78995981331,
#   'volume_24h': 29436076512.222034,
#   'volume_change_24h': -6.1104,
#   'max_supply': 21000000.0,
#   'circulating_supply': 19836878.0,
#   'total_supply': 19836878.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 1,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 1027,
#   'name': 'Ethereum',
#   'symbol': 'ETH',
#   'date_added': '2015-08-07T00:00:00.000Z',
#   'Price': 1935.8155746012596,
#   'volume_24h': 12816731366.172659,
#   'volume_change_24h': -30.3381,
#   'max_supply': None,
#   'circulating_supply': 120614183.5975569,
#   'total_supply': 120614183.5975569,
#   'infinite_supply': 'True',
#   'cmc_rank': 2,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 825,
#   'name': 'Tether USDt',
#   'symbol': 'USDT',
#   'date_added': '2015-02-25T00:00:00.000Z',
#   'Price': 1.0000848462505614,
#   'volume_24h': 61522047076.00157,
#   'volume_change_24h': -11.0094,
#   'max_supply': None,
#   'circulating_supply': 143346765715.551,
#   'total_supply': 144554112158.81436,
#   'infinite_supply': 'True',
#   'cmc_rank': 3,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 52,
#   'name': 'XRP',
#   'symbol': 'XRP',
#   'date_added': '2013-08-04T00:00:00.000Z',
#   'Price': 2.357569467548601,
#   'volume_24h': 4474045810.298453,
#   'volume_change_24h': -19.5404,
#   'max_supply': 100000000000.0,
#   'circulating_supply': 58108919817.0,
#   'total_supply': 99986343905.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 4,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 1839,
#   'name': 'BNB',
#   'symbol': 'BNB',
#   'date_added': '2017-07-25T00:00:00.000Z',
#   'Price': 588.495836666123,
#   'volume_24h': 1562637386.0104766,
#   'volume_change_24h': -35.2385,
#   'max_supply': None,
#   'circulating_supply': 142474992.95,
#   'total_supply': 142474992.95,
#   'infinite_supply': 'False',
#   'cmc_rank': 5,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 5426,
#   'name': 'Solana',
#   'symbol': 'SOL',
#   'date_added': '2020-04-10T00:00:00.000Z',
#   'Price': 134.10575152034278,
#   'volume_24h': 3004777420.999797,
#   'volume_change_24h': -0.2194,
#   'max_supply': None,
#   'circulating_supply': 509564914.33139604,
#   'total_supply': 596189075.1958779,
#   'infinite_supply': 'True',
#   'cmc_rank': 6,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 3408,
#   'name': 'USDC',
#   'symbol': 'USDC',
#   'date_added': '2018-10-08T00:00:00.000Z',
#   'Price': 0.9998995750402716,
#   'volume_24h': 9291946678.669954,
#   'volume_change_24h': -23.0389,
#   'max_supply': None,
#   'circulating_supply': 58501966710.66599,
#   'total_supply': 58501966710.66599,
#   'infinite_supply': 'False',
#   'cmc_rank': 7,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 2010,
#   'name': 'Cardano',
#   'symbol': 'ADA',
#   'date_added': '2017-10-01T00:00:00.000Z',
#   'Price': 0.7391668572996885,
#   'volume_24h': 1011885078.054758,
#   'volume_change_24h': -14.2581,
#   'max_supply': 45000000000.0,
#   'circulating_supply': 35230631106.53998,
#   'total_supply': 44994938498.2471,
#   'infinite_supply': 'False',
#   'cmc_rank': 8,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 74,
#   'name': 'Dogecoin',
#   'symbol': 'DOGE',
#   'date_added': '2013-12-15T00:00:00.000Z',
#   'Price': 0.17181724251586478,
#   'volume_24h': 1066889108.4142364,
#   'volume_change_24h': -27.2044,
#   'max_supply': None,
#   'circulating_supply': 148428216383.70517,
#   'total_supply': 148428216383.70517,
#   'infinite_supply': 'True',
#   'cmc_rank': 9,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 1958,
#   'name': 'TRON',
#   'symbol': 'TRX',
#   'date_added': '2017-09-13T00:00:00.000Z',
#   'Price': 0.221800436799965,
#   'volume_24h': 606267204.3642774,
#   'volume_change_24h': 2.0528,
#   'max_supply': None,
#   'circulating_supply': 95027500544.23929,
#   'total_supply': 95027508328.3081,
#   'infinite_supply': 'True',
#   'cmc_rank': 10,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 35697,
#   'name': 'Pi',
#   'symbol': 'PI',
#   'date_added': '2025-02-11T07:16:10.000Z',
#   'Price': 1.520284672253384,
#   'volume_24h': 677445570.7869722,
#   'volume_change_24h': 4.4042,
#   'max_supply': 100000000000.0,
#   'circulating_supply': 7071642142.047408,
#   'total_supply': 100000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 11,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 1975,
#   'name': 'Chainlink',
#   'symbol': 'LINK',
#   'date_added': '2017-09-20T00:00:00.000Z',
#   'Price': 14.546585069751284,
#   'volume_24h': 850499309.3130183,
#   'volume_change_24h': 121.6083,
#   'max_supply': None,
#   'circulating_supply': 638099970.4527867,
#   'total_supply': 1000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 12,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 3957,
#   'name': 'UNUS SED LEO',
#   'symbol': 'LEO',
#   'date_added': '2019-05-21T00:00:00.000Z',
#   'Price': 9.80193527668661,
#   'volume_24h': 2868808.95707105,
#   'volume_change_24h': 5.0288,
#   'max_supply': None,
#   'circulating_supply': 923938491.9,
#   'total_supply': 985239504.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 13,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 512,
#   'name': 'Stellar',
#   'symbol': 'XLM',
#   'date_added': '2014-08-05T00:00:00.000Z',
#   'Price': 0.2752806269672474,
#   'volume_24h': 310360530.1323512,
#   'volume_change_24h': -30.6948,
#   'max_supply': 50001806812.0,
#   'circulating_supply': 30707887633.65079,
#   'total_supply': 50001786894.44301,
#   'infinite_supply': 'False',
#   'cmc_rank': 14,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 4642,
#   'name': 'Hedera',
#   'symbol': 'HBAR',
#   'date_added': '2019-09-17T00:00:00.000Z',
#   'Price': 0.19356464703410678,
#   'volume_24h': 320377474.79708636,
#   'volume_change_24h': -20.0587,
#   'max_supply': 50000000000.0,
#   'circulating_supply': 42217580820.66579,
#   'total_supply': 50000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 15,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 5805,
#   'name': 'Avalanche',
#   'symbol': 'AVAX',
#   'date_added': '2020-07-13T00:00:00.000Z',
#   'Price': 19.110334962199826,
#   'volume_24h': 277050880.6794701,
#   'volume_change_24h': -19.3822,
#   'max_supply': 715748719.0,
#   'circulating_supply': 414361136.9087372,
#   'total_supply': 451030636.9087372,
#   'infinite_supply': 'False',
#   'cmc_rank': 16,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 20947,
#   'name': 'Sui',
#   'symbol': 'SUI',
#   'date_added': '2022-07-12T08:03:11.000Z',
#   'Price': 2.3629865161308445,
#   'volume_24h': 786677856.6825371,
#   'volume_change_24h': 0.8411,
#   'max_supply': 10000000000.0,
#   'circulating_supply': 3169845047.4838877,
#   'total_supply': 10000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 17,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 5994,
#   'name': 'Shiba Inu',
#   'symbol': 'SHIB',
#   'date_added': '2020-08-01T00:00:00.000Z',
#   'Price': 1.2668503417027917e-05,
#   'volume_24h': 187503456.21101367,
#   'volume_change_24h': -0.5935,
#   'max_supply': 589552695333683.0,
#   'circulating_supply': 589252986114260.9,
#   'total_supply': 589506900916172.8,
#   'infinite_supply': 'False',
#   'cmc_rank': 18,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 11419,
#   'name': 'Toncoin',
#   'symbol': 'TON',
#   'date_added': '2021-08-26T13:40:22.000Z',
#   'Price': 2.910626007465746,
#   'volume_24h': 160454775.92046505,
#   'volume_change_24h': 14.6306,
#   'max_supply': None,
#   'circulating_supply': 2481240119.8024983,
#   'total_supply': 5124620289.743499,
#   'infinite_supply': 'True',
#   'cmc_rank': 19,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 2,
#   'name': 'Litecoin',
#   'symbol': 'LTC',
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'Price': 92.08231139961003,
#   'volume_24h': 495559832.94463754,
#   'volume_change_24h': -4.5312,
#   'max_supply': 84000000.0,
#   'circulating_supply': 75558468.3040892,
#   'total_supply': 84000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 20,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 1831,
#   'name': 'Bitcoin Cash',
#   'symbol': 'BCH',
#   'date_added': '2017-07-23T00:00:00.000Z',
#   'Price': 330.08176471735123,
#   'volume_24h': 272513957.07475084,
#   'volume_change_24h': -11.3745,
#   'max_supply': 21000000.0,
#   'circulating_supply': 19842084.375,
#   'total_supply': 19842084.375,
#   'infinite_supply': 'False',
#   'cmc_rank': 21,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 6636,
#   'name': 'Polkadot',
#   'symbol': 'DOT',
#   'date_added': '2020-08-19T00:00:00.000Z',
#   'Price': 4.196830896218094,
#   'volume_24h': 210882339.30204076,
#   'volume_change_24h': 6.4281,
#   'max_supply': None,
#   'circulating_supply': 1557792146.150096,
#   'total_supply': 1557792146.150096,
#   'infinite_supply': 'True',
#   'cmc_rank': 22,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 6536,
#   'name': 'MANTRA',
#   'symbol': 'OM',
#   'date_added': '2020-08-11T00:00:00.000Z',
#   'Price': 6.252803322310533,
#   'volume_24h': 68170221.16712639,
#   'volume_change_24h': 8.9269,
#   'max_supply': None,
#   'circulating_supply': 983664325.4300001,
#   'total_supply': 1811823713.39,
#   'infinite_supply': 'True',
#   'cmc_rank': 23,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 29470,
#   'name': 'Ethena USDe',
#   'symbol': 'USDe',
#   'date_added': '2024-02-20T11:05:01.000Z',
#   'Price': 0.9999490196602493,
#   'volume_24h': 63492473.11869608,
#   'volume_change_24h': 4.4414,
#   'max_supply': None,
#   'circulating_supply': 5460568000.550031,
#   'total_supply': 5460568000.550031,
#   'infinite_supply': 'True',
#   'cmc_rank': 24,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 4943,
#   'name': 'Dai',
#   'symbol': 'DAI',
#   'date_added': '2019-11-22T00:00:00.000Z',
#   'Price': 1.000069747482662,
#   'volume_24h': 83224813.51758981,
#   'volume_change_24h': -29.5379,
#   'max_supply': None,
#   'circulating_supply': 5365382702.664872,
#   'total_supply': 5365382702.664872,
#   'infinite_supply': 'True',
#   'cmc_rank': 25,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 11092,
#   'name': 'Bitget Token',
#   'symbol': 'BGB',
#   'date_added': '2021-07-29T00:00:00.000Z',
#   'Price': 4.444801416423675,
#   'volume_24h': 242101243.01105788,
#   'volume_change_24h': 70.6134,
#   'max_supply': None,
#   'circulating_supply': 1200000000.0,
#   'total_supply': 1200000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 26,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 32196,
#   'name': 'Hyperliquid',
#   'symbol': 'HYPE',
#   'date_added': '2024-07-15T10:14:50.000Z',
#   'Price': 14.375983753056346,
#   'volume_24h': 140097994.91290185,
#   'volume_change_24h': -2.8888,
#   'max_supply': 1000000000.0,
#   'circulating_supply': 333928180.0,
#   'total_supply': 999993930.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 27,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 328,
#   'name': 'Monero',
#   'symbol': 'XMR',
#   'date_added': '2014-05-21T00:00:00.000Z',
#   'Price': 209.69411327592584,
#   'volume_24h': 55899837.60461931,
#   'volume_change_24h': 6.1104,
#   'max_supply': None,
#   'circulating_supply': 18446744.07370955,
#   'total_supply': 18446744.07370955,
#   'infinite_supply': 'True',
#   'cmc_rank': 28,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 7083,
#   'name': 'Uniswap',
#   'symbol': 'UNI',
#   'date_added': '2020-09-17T00:00:00.000Z',
#   'Price': 6.1062861962333415,
#   'volume_24h': 140153096.45690492,
#   'volume_change_24h': -2.3926,
#   'max_supply': None,
#   'circulating_supply': 600585117.71,
#   'total_supply': 1000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 29,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 6535,
#   'name': 'NEAR Protocol',
#   'symbol': 'NEAR',
#   'date_added': '2020-08-11T00:00:00.000Z',
#   'Price': 2.659059023033101,
#   'volume_24h': 278574662.57318985,
#   'volume_change_24h': 37.9268,
#   'max_supply': None,
#   'circulating_supply': 1194977992.0,
#   'total_supply': 1239984620.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 30,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 21794,
#   'name': 'Aptos',
#   'symbol': 'APT',
#   'date_added': '2022-10-19T01:50:25.000Z',
#   'Price': 5.245908655148398,
#   'volume_24h': 133943179.29239504,
#   'volume_change_24h': -17.475,
#   'max_supply': None,
#   'circulating_supply': 602040773.768407,
#   'total_supply': 1144057066.6863105,
#   'infinite_supply': 'True',
#   'cmc_rank': 31,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 24478,
#   'name': 'Pepe',
#   'symbol': 'PEPE',
#   'date_added': '2023-04-17T06:18:08.000Z',
#   'Price': 7.134856144376107e-06,
#   'volume_24h': 748340714.7680593,
#   'volume_change_24h': -33.2108,
#   'max_supply': 420690000000000.0,
#   'circulating_supply': 420689899653543.56,
#   'total_supply': 420689899653543.56,
#   'infinite_supply': 'False',
#   'cmc_rank': 32,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 3897,
#   'name': 'OKB',
#   'symbol': 'OKB',
#   'date_added': '2019-04-30T00:00:00.000Z',
#   'Price': 46.12042704598365,
#   'volume_24h': 10283327.04008314,
#   'volume_change_24h': 170.4397,
#   'max_supply': None,
#   'circulating_supply': 60000000.0,
#   'total_supply': 300000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 33,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 21159,
#   'name': 'Ondo',
#   'symbol': 'ONDO',
#   'date_added': '2024-01-18T12:06:25.000Z',
#   'Price': 0.8741948727745567,
#   'volume_24h': 147638829.1207764,
#   'volume_change_24h': -2.1739,
#   'max_supply': None,
#   'circulating_supply': 3159107529.0,
#   'total_supply': 10000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 34,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 8916,
#   'name': 'Internet Computer',
#   'symbol': 'ICP',
#   'date_added': '2021-03-23T00:00:00.000Z',
#   'Price': 5.697521978075406,
#   'volume_24h': 57193946.85981638,
#   'volume_change_24h': -14.5168,
#   'max_supply': None,
#   'circulating_supply': 481403778.9797285,
#   'total_supply': 530279727.7375926,
#   'infinite_supply': 'True',
#   'cmc_rank': 35,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 1321,
#   'name': 'Ethereum Classic',
#   'symbol': 'ETC',
#   'date_added': '2016-07-24T00:00:00.000Z',
#   'Price': 18.118888979192413,
#   'volume_24h': 113314032.08496653,
#   'volume_change_24h': 9.6051,
#   'max_supply': 210700000.0,
#   'circulating_supply': 151115983.1254495,
#   'total_supply': 210700000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 36,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 7278,
#   'name': 'Aave',
#   'symbol': 'AAVE',
#   'date_added': '2020-10-02T00:00:00.000Z',
#   'Price': 175.06699383163337,
#   'volume_24h': 334776883.86329466,
#   'volume_change_24h': -9.5651,
#   'max_supply': None,
#   'circulating_supply': 15088630.3246388,
#   'total_supply': 16000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 37,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 27075,
#   'name': 'Mantle',
#   'symbol': 'MNT',
#   'date_added': '2023-07-17T11:00:31.000Z',
#   'Price': 0.7362312002042903,
#   'volume_24h': 58439934.73786767,
#   'volume_change_24h': -37.0605,
#   'max_supply': 6219316795.0,
#   'circulating_supply': 3364694382.8368406,
#   'total_supply': 6219316794.99,
#   'infinite_supply': 'False',
#   'cmc_rank': 38,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 35336,
#   'name': 'OFFICIAL TRUMP',
#   'symbol': 'TRUMP',
#   'date_added': '2025-01-18T04:19:35.000Z',
#   'Price': 12.00910400787689,
#   'volume_24h': 1537517325.1298637,
#   'volume_change_24h': 37.2231,
#   'max_supply': 999999993.45,
#   'circulating_supply': 199999528.701504,
#   'total_supply': 999999551.465504,
#   'infinite_supply': 'False',
#   'cmc_rank': 39,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 3635,
#   'name': 'Cronos',
#   'symbol': 'CRO',
#   'date_added': '2018-12-14T00:00:00.000Z',
#   'Price': 0.08394109082629005,
#   'volume_24h': 34598634.43315607,
#   'volume_change_24h': 1.3255,
#   'max_supply': None,
#   'circulating_supply': 26571560696.0,
#   'total_supply': 30000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 40,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 22974,
#   'name': 'Bittensor',
#   'symbol': 'TAO',
#   'date_added': '2023-03-06T05:20:00.000Z',
#   'Price': 255.4571235512119,
#   'volume_24h': 98131360.97325373,
#   'volume_change_24h': -8.9138,
#   'max_supply': 21000000.0,
#   'circulating_supply': 8456364.0,
#   'total_supply': 8456364.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 41,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 3077,
#   'name': 'VeChain',
#   'symbol': 'VET',
#   'date_added': '2017-08-22T00:00:00.000Z',
#   'Price': 0.02494221980528731,
#   'volume_24h': 57214551.98812436,
#   'volume_change_24h': -22.9613,
#   'max_supply': 86712634466.0,
#   'circulating_supply': 85985041177.0,
#   'total_supply': 85985041177.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 42,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 26081,
#   'name': 'First Digital USD',
#   'symbol': 'FDUSD',
#   'date_added': '2023-07-26T04:26:40.000Z',
#   'Price': 0.9989193728977979,
#   'volume_24h': 4338929658.775341,
#   'volume_change_24h': -21.5132,
#   'max_supply': None,
#   'circulating_supply': 2078518049.61862,
#   'total_supply': 2078518049.61862,
#   'infinite_supply': 'False',
#   'cmc_rank': 43,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 22861,
#   'name': 'Celestia',
#   'symbol': 'TIA',
#   'date_added': '2023-10-31T16:51:41.000Z',
#   'Price': 3.5809424806018817,
#   'volume_24h': 97145468.80734238,
#   'volume_change_24h': -24.4036,
#   'max_supply': None,
#   'circulating_supply': 561379525.355637,
#   'total_supply': 1108760547.944865,
#   'infinite_supply': 'False',
#   'cmc_rank': 44,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 20396,
#   'name': 'Kaspa',
#   'symbol': 'KAS',
#   'date_added': '2022-06-01T00:03:58.000Z',
#   'Price': 0.0768013869108119,
#   'volume_24h': 71771383.81205076,
#   'volume_change_24h': 0.9886,
#   'max_supply': 28704026601.0,
#   'circulating_supply': 25858056725.829456,
#   'total_supply': 25858056725.829456,
#   'infinite_supply': 'False',
#   'cmc_rank': 45,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 28321,
#   'name': 'POL (prev. MATIC)',
#   'symbol': 'POL',
#   'date_added': '2023-10-30T14:43:57.000Z',
#   'Price': 0.2174862545179893,
#   'volume_24h': 92893332.94304547,
#   'volume_change_24h': -3.4661,
#   'max_supply': None,
#   'circulating_supply': 8593612638.829615,
#   'total_supply': 10382883669.119854,
#   'infinite_supply': 'False',
#   'cmc_rank': 46,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 2280,
#   'name': 'Filecoin',
#   'symbol': 'FIL',
#   'date_added': '2017-12-13T00:00:00.000Z',
#   'Price': 2.8935423198683026,
#   'volume_24h': 122033762.87741195,
#   'volume_change_24h': -2.2474,
#   'max_supply': None,
#   'circulating_supply': 643878691.0,
#   'total_supply': 1959608269.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 47,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 4269,
#   'name': 'GateToken',
#   'symbol': 'GT',
#   'date_added': '2019-08-20T00:00:00.000Z',
#   'Price': 21.457996624674156,
#   'volume_24h': 23812103.6880899,
#   'volume_change_24h': -18.6077,
#   'max_supply': None,
#   'circulating_supply': 85831192.49018952,
#   'total_supply': 300000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 48,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 4030,
#   'name': 'Algorand',
#   'symbol': 'ALGO',
#   'date_added': '2019-06-20T00:00:00.000Z',
#   'Price': 0.2005125026356359,
#   'volume_24h': 75677532.53269377,
#   'volume_change_24h': -18.805,
#   'max_supply': 10000000000.0,
#   'circulating_supply': 8497785479.146809,
#   'total_supply': 10000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 49,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 5690,
#   'name': 'Render',
#   'symbol': 'RENDER',
#   'date_added': '2020-06-11T00:00:00.000Z',
#   'Price': 3.20791596439155,
#   'volume_24h': 58294532.60911121,
#   'volume_change_24h': -5.3604,
#   'max_supply': 644168762.0,
#   'circulating_supply': 517716590.05628264,
#   'total_supply': 532476763.3362826,
#   'infinite_supply': 'False',
#   'cmc_rank': 50,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 3794,
#   'name': 'Cosmos',
#   'symbol': 'ATOM',
#   'date_added': '2019-03-14T00:00:00.000Z',
#   'Price': 4.209138959853043,
#   'volume_24h': 115914407.70925696,
#   'volume_change_24h': 3.7744,
#   'max_supply': None,
#   'circulating_supply': 390934204.0,
#   'total_supply': 390934204.0,
#   'infinite_supply': 'True',
#   'cmc_rank': 51,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 11841,
#   'name': 'Arbitrum',
#   'symbol': 'ARB',
#   'date_added': '2023-03-23T12:50:11.000Z',
#   'Price': 0.3650643508332297,
#   'volume_24h': 143468536.63173833,
#   'volume_change_24h': -7.5955,
#   'max_supply': None,
#   'circulating_supply': 4419312625.0,
#   'total_supply': 10000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 52,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 32684,
#   'name': 'Sonic (prev. FTM)',
#   'symbol': 'S',
#   'date_added': '2025-01-03T14:11:26.000Z',
#   'Price': 0.5447396955135759,
#   'volume_24h': 223635895.3408776,
#   'volume_change_24h': 7.4143,
#   'max_supply': None,
#   'circulating_supply': 2880000000.0,
#   'total_supply': 3175000000.0,
#   'infinite_supply': 'True',
#   'cmc_rank': 53,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 35626,
#   'name': 'Story',
#   'symbol': 'IP',
#   'date_added': '2025-02-06T07:02:40.000Z',
#   'Price': 6.028411265959986,
#   'volume_24h': 141012434.12269932,
#   'volume_change_24h': 4.577,
#   'max_supply': None,
#   'circulating_supply': 250000000.0,
#   'total_supply': 1000000000.0,
#   'infinite_supply': 'True',
#   'cmc_rank': 54,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 7326,
#   'name': 'DeXe',
#   'symbol': 'DEXE',
#   'date_added': '2020-10-07T00:00:00.000Z',
#   'Price': 17.34944720548573,
#   'volume_24h': 23098544.75363803,
#   'volume_change_24h': -25.1635,
#   'max_supply': None,
#   'circulating_supply': 83733347.49799643,
#   'total_supply': 96504599.33609451,
#   'infinite_supply': 'False',
#   'cmc_rank': 55,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 29210,
#   'name': 'Jupiter',
#   'symbol': 'JUP',
#   'date_added': '2024-01-31T08:38:13.000Z',
#   'Price': 0.5327088189132214,
#   'volume_24h': 50673253.93027312,
#   'volume_change_24h': -3.1387,
#   'max_supply': 10000000000.0,
#   'circulating_supply': 2690911111.1,
#   'total_supply': 6999978366.897344,
#   'infinite_supply': 'False',
#   'cmc_rank': 56,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 11840,
#   'name': 'Optimism',
#   'symbol': 'OP',
#   'date_added': '2022-05-31T16:19:46.000Z',
#   'Price': 0.8824722458890365,
#   'volume_24h': 100635833.76522961,
#   'volume_change_24h': -30.3605,
#   'max_supply': 4294967296.0,
#   'circulating_supply': 1620705846.0,
#   'total_supply': 4294967296.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 57,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 2087,
#   'name': 'KuCoin Token',
#   'symbol': 'KCS',
#   'date_added': '2017-10-24T00:00:00.000Z',
#   'Price': 11.09178483533493,
#   'volume_24h': 728680.62422399,
#   'volume_change_24h': -23.5657,
#   'max_supply': 200000000.0,
#   'circulating_supply': 122561753.85133564,
#   'total_supply': 142561753.85133564,
#   'infinite_supply': 'False',
#   'cmc_rank': 58,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 3773,
#   'name': 'Artificial Superintelligence Alliance',
#   'symbol': 'FET',
#   'date_added': '2019-03-02T00:00:00.000Z',
#   'Price': 0.5184447855692853,
#   'volume_24h': 110261167.09218042,
#   'volume_change_24h': -10.922,
#   'max_supply': 2719493897.0,
#   'circulating_supply': 2389251033.7228017,
#   'total_supply': 2714493896.672,
#   'infinite_supply': 'False',
#   'cmc_rank': 59,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 30171,
#   'name': 'Ethena',
#   'symbol': 'ENA',
#   'date_added': '2024-03-29T04:42:08.000Z',
#   'Price': 0.35814865192265594,
#   'volume_24h': 266365167.18066204,
#   'volume_change_24h': 23.7903,
#   'max_supply': None,
#   'circulating_supply': 3223437500.0,
#   'total_supply': 15000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 60,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 32452,
#   'name': 'Movement',
#   'symbol': 'MOVE',
#   'date_added': '2024-07-29T03:27:27.000Z',
#   'Price': 0.45768093242080454,
#   'volume_24h': 68945667.76185504,
#   'volume_change_24h': -33.6075,
#   'max_supply': 10000000000.0,
#   'circulating_supply': 2400000000.0,
#   'total_supply': 10000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 61,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 2634,
#   'name': 'XDC Network',
#   'symbol': 'XDC',
#   'date_added': '2018-04-12T00:00:00.000Z',
#   'Price': 0.0691790645780462,
#   'volume_24h': 36625669.85484673,
#   'volume_change_24h': -8.7767,
#   'max_supply': None,
#   'circulating_supply': 15694839394.05,
#   'total_supply': 37978374430.05,
#   'infinite_supply': 'False',
#   'cmc_rank': 62,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 1518,
#   'name': 'Maker',
#   'symbol': 'MKR',
#   'date_added': '2017-01-29T00:00:00.000Z',
#   'Price': 1210.9919169594834,
#   'volume_24h': 125142356.92040658,
#   'volume_change_24h': 19.4552,
#   'max_supply': 1000000.0,
#   'circulating_supply': 848000.7199913,
#   'total_supply': 874245.26729794,
#   'infinite_supply': 'False',
#   'cmc_rank': 63,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 7226,
#   'name': 'Injective',
#   'symbol': 'INJ',
#   'date_added': '2020-09-29T00:00:00.000Z',
#   'Price': 10.223184904910331,
#   'volume_24h': 104479763.35848059,
#   'volume_change_24h': -10.0257,
#   'max_supply': None,
#   'circulating_supply': 98970935.41,
#   'total_supply': 100000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 64,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 4847,
#   'name': 'Stacks',
#   'symbol': 'STX',
#   'date_added': '2019-10-28T00:00:00.000Z',
#   'Price': 0.6490483575956335,
#   'volume_24h': 32862935.12897303,
#   'volume_change_24h': 17.2103,
#   'max_supply': 1818000000.0,
#   'circulating_supply': 1516932087.63665,
#   'total_supply': 1516932087.63665,
#   'infinite_supply': 'False',
#   'cmc_rank': 65,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 13502,
#   'name': 'Worldcoin',
#   'symbol': 'WLD',
#   'date_added': '2021-10-28T15:31:43.000Z',
#   'Price': 0.8822996299143523,
#   'volume_24h': 111764205.42962754,
#   'volume_change_24h': -12.6364,
#   'max_supply': None,
#   'circulating_supply': 1105693571.31713,
#   'total_supply': 10000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 66,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 10603,
#   'name': 'Immutable',
#   'symbol': 'IMX',
#   'date_added': '2021-06-24T00:00:00.000Z',
#   'Price': 0.5505523071703887,
#   'volume_24h': 29688995.49918491,
#   'volume_change_24h': -11.8477,
#   'max_supply': 2000000000.0,
#   'circulating_supply': 1768317543.3898141,
#   'total_supply': 2000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 67,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 23149,
#   'name': 'Sei',
#   'symbol': 'SEI',
#   'date_added': '2023-08-14T07:35:00.000Z',
#   'Price': 0.20555607164634507,
#   'volume_24h': 112796320.3217992,
#   'volume_change_24h': 7.5527,
#   'max_supply': None,
#   'circulating_supply': 4657499999.0,
#   'total_supply': 10000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 68,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 7950,
#   'name': 'Flare',
#   'symbol': 'FLR',
#   'date_added': '2020-12-11T00:00:00.000Z',
#   'Price': 0.015365640672324796,
#   'volume_24h': 10728437.87957534,
#   'volume_change_24h': 15.5394,
#   'max_supply': None,
#   'circulating_supply': 60996126627.4473,
#   'total_supply': 103140781941.84601,
#   'infinite_supply': 'False',
#   'cmc_rank': 69,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 3155,
#   'name': 'Quant',
#   'symbol': 'QNT',
#   'date_added': '2018-08-10T00:00:00.000Z',
#   'Price': 76.53802821396022,
#   'volume_24h': 20183311.41831733,
#   'volume_change_24h': -13.6388,
#   'max_supply': 14881364.0,
#   'circulating_supply': 12072738.0,
#   'total_supply': 14881364.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 70,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 6719,
#   'name': 'The Graph',
#   'symbol': 'GRT',
#   'date_added': '2020-12-17T00:00:00.000Z',
#   'Price': 0.0948969965765754,
#   'volume_24h': 35392011.39457026,
#   'volume_change_24h': -5.4577,
#   'max_supply': None,
#   'circulating_supply': 9548531509.165474,
#   'total_supply': 10799706720.163599,
#   'infinite_supply': 'False',
#   'cmc_rank': 71,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 2416,
#   'name': 'Theta Network',
#   'symbol': 'THETA',
#   'date_added': '2018-01-17T00:00:00.000Z',
#   'Price': 0.9002606737175546,
#   'volume_24h': 24206631.63346459,
#   'volume_change_24h': -18.5852,
#   'max_supply': 1000000000.0,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 72,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 8000,
#   'name': 'Lido DAO',
#   'symbol': 'LDO',
#   'date_added': '2020-12-15T00:00:00.000Z',
#   'Price': 0.9551952337535062,
#   'volume_24h': 97194186.4856135,
#   'volume_change_24h': 5.2889,
#   'max_supply': None,
#   'circulating_supply': 897146051.8587132,
#   'total_supply': 1000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 73,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 23095,
#   'name': 'Bonk',
#   'symbol': 'BONK',
#   'date_added': '2022-12-30T06:58:50.000Z',
#   'Price': 1.0985440924315836e-05,
#   'volume_24h': 72789212.20728453,
#   'volume_change_24h': -9.712,
#   'max_supply': 88872433754423.19,
#   'circulating_supply': 77811005704223.86,
#   'total_supply': 88855844941977.78,
#   'infinite_supply': 'False',
#   'cmc_rank': 74,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 1765,
#   'name': 'EOS',
#   'symbol': 'EOS',
#   'date_added': '2017-07-01T00:00:00.000Z',
#   'Price': 0.5096631364195783,
#   'volume_24h': 69568176.75465557,
#   'volume_change_24h': -12.4672,
#   'max_supply': 2100000000.0,
#   'circulating_supply': 1552409504.3636,
#   'total_supply': 2100000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 75,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 27772,
#   'name': 'PayPal USD',
#   'symbol': 'PYUSD',
#   'date_added': '2023-08-21T14:30:00.000Z',
#   'Price': 1.0000085574971929,
#   'volume_24h': 256830215.21761274,
#   'volume_change_24h': -26.5603,
#   'max_supply': None,
#   'circulating_supply': 760806608.312222,
#   'total_supply': 760806608.312222,
#   'infinite_supply': 'False',
#   'cmc_rank': 76,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 5176,
#   'name': 'Tether Gold',
#   'symbol': 'XAUt',
#   'date_added': '2020-02-07T00:00:00.000Z',
#   'Price': 2984.2432134859964,
#   'volume_24h': 5212099.98255141,
#   'volume_change_24h': 37.477,
#   'max_supply': None,
#   'circulating_supply': 246524.0,
#   'total_supply': 246524.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 77,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 7080,
#   'name': 'Gala',
#   'symbol': 'GALA',
#   'date_added': '2020-09-16T00:00:00.000Z',
#   'Price': 0.016796215625331196,
#   'volume_24h': 60873888.70083427,
#   'volume_change_24h': -10.6668,
#   'max_supply': 50000000000.0,
#   'circulating_supply': 43504919288.53921,
#   'total_supply': 43504919288.53914,
#   'infinite_supply': 'False',
#   'cmc_rank': 78,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 2011,
#   'name': 'Tezos',
#   'symbol': 'XTZ',
#   'date_added': '2017-10-06T00:00:00.000Z',
#   'Price': 0.7054929477556109,
#   'volume_24h': 23982110.81643282,
#   'volume_change_24h': -13.7371,
#   'max_supply': None,
#   'circulating_supply': 1034549288.72322,
#   'total_supply': 1054802458.13169,
#   'infinite_supply': 'True',
#   'cmc_rank': 79,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 6210,
#   'name': 'The Sandbox',
#   'symbol': 'SAND',
#   'date_added': '2020-08-05T00:00:00.000Z',
#   'Price': 0.287190996231748,
#   'volume_24h': 60791361.0483361,
#   'volume_change_24h': -13.4781,
#   'max_supply': None,
#   'circulating_supply': 2469357126.2233224,
#   'total_supply': 3000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 80,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 2694,
#   'name': 'Nexo',
#   'symbol': 'NEXO',
#   'date_added': '2018-05-01T00:00:00.000Z',
#   'Price': 1.087683138572255,
#   'volume_24h': 8313340.21413505,
#   'volume_change_24h': -6.9127,
#   'max_supply': None,
#   'circulating_supply': 646145839.5746847,
#   'total_supply': 1000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 81,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 28541,
#   'name': 'Jito',
#   'symbol': 'JTO',
#   'date_added': '2023-12-07T16:04:41.000Z',
#   'Price': 2.272204767050361,
#   'volume_24h': 32620365.6929202,
#   'volume_change_24h': -16.0168,
#   'max_supply': None,
#   'circulating_supply': 304471682.9,
#   'total_supply': 999999764.1551902,
#   'infinite_supply': 'False',
#   'cmc_rank': 82,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 8425,
#   'name': 'JasmyCoin',
#   'symbol': 'JASMY',
#   'date_added': '2021-02-11T00:00:00.000Z',
#   'Price': 0.013938684395362774,
#   'volume_24h': 57012110.80815985,
#   'volume_change_24h': 13.0801,
#   'max_supply': 50000000000.0,
#   'circulating_supply': 49444999677.16958,
#   'total_supply': 50000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 83,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 16086,
#   'name': 'BitTorrent [New]',
#   'symbol': 'BTT',
#   'date_added': '2019-01-31T00:00:00.000Z',
#   'Price': 6.975391636307144e-07,
#   'volume_24h': 22274502.33599349,
#   'volume_change_24h': 12.5181,
#   'max_supply': None,
#   'circulating_supply': 986061142857000.0,
#   'total_supply': 990000000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 84,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 3602,
#   'name': 'Bitcoin SV',
#   'symbol': 'BSV',
#   'date_added': '2018-11-09T00:00:00.000Z',
#   'Price': 34.28989935266714,
#   'volume_24h': 58467285.98822226,
#   'volume_change_24h': -14.0868,
#   'max_supply': None,
#   'circulating_supply': 19837646.875,
#   'total_supply': 19837646.875,
#   'infinite_supply': 'False',
#   'cmc_rank': 85,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 1720,
#   'name': 'IOTA',
#   'symbol': 'IOTA',
#   'date_added': '2017-06-13T00:00:00.000Z',
#   'Price': 0.18416051853247717,
#   'volume_24h': 21621503.24666087,
#   'volume_change_24h': -22.5107,
#   'max_supply': None,
#   'circulating_supply': 3669672848.0,
#   'total_supply': 3669672848.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 86,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 24647,
#   'name': 'Berachain',
#   'symbol': 'BERA',
#   'date_added': '2025-02-06T13:00:00.000Z',
#   'Price': 6.197438135686913,
#   'volume_24h': 78211569.12736505,
#   'volume_change_24h': -31.5153,
#   'max_supply': None,
#   'circulating_supply': 107480000.0,
#   'total_supply': 500000000.0,
#   'infinite_supply': 'True',
#   'cmc_rank': 87,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 32880,
#   'name': 'Kaia',
#   'symbol': 'KAIA',
#   'date_added': '2024-10-29T05:17:50.000Z',
#   'Price': 0.11141316759766554,
#   'volume_24h': 16451865.46449412,
#   'volume_change_24h': -32.8195,
#   'max_supply': None,
#   'circulating_supply': 5967787106.401215,
#   'total_supply': 5967787077.92494,
#   'infinite_supply': 'True',
#   'cmc_rank': 88,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 4558,
#   'name': 'Flow',
#   'symbol': 'FLOW',
#   'date_added': '2021-01-27T00:00:00.000Z',
#   'Price': 0.40603535810863917,
#   'volume_24h': 25116183.02248431,
#   'volume_change_24h': -18.3498,
#   'max_supply': None,
#   'circulating_supply': 1569592535.0126963,
#   'total_supply': 1569592535.0126963,
#   'infinite_supply': 'True',
#   'cmc_rank': 89,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 4705,
#   'name': 'PAX Gold',
#   'symbol': 'PAXG',
#   'date_added': '2019-09-26T00:00:00.000Z',
#   'Price': 2995.114938874153,
#   'volume_24h': 42128163.45030418,
#   'volume_change_24h': 28.9528,
#   'max_supply': None,
#   'circulating_supply': 210780.179,
#   'total_supply': 210780.179,
#   'infinite_supply': 'True',
#   'cmc_rank': 90,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 13855,
#   'name': 'Ethereum Name Service',
#   'symbol': 'ENS',
#   'date_added': '2021-11-09T01:31:29.000Z',
#   'Price': 17.006524016760043,
#   'volume_24h': 45172628.42430925,
#   'volume_change_24h': -20.9791,
#   'max_supply': None,
#   'circulating_supply': 35599750.83870389,
#   'total_supply': 100000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 91,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 10804,
#   'name': 'FLOKI',
#   'symbol': 'FLOKI',
#   'date_added': '2021-07-09T00:00:00.000Z',
#   'Price': 6.202815406894019e-05,
#   'volume_24h': 94357959.17218086,
#   'volume_change_24h': -34.7544,
#   'max_supply': None,
#   'circulating_supply': 9626536735169.504,
#   'total_supply': 9662665184590.756,
#   'infinite_supply': 'False',
#   'cmc_rank': 92,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 1376,
#   'name': 'Neo',
#   'symbol': 'NEO',
#   'date_added': '2016-09-08T00:00:00.000Z',
#   'Price': 8.088481640006014,
#   'volume_24h': 23136832.51921397,
#   'volume_change_24h': -11.9414,
#   'max_supply': None,
#   'circulating_supply': 70538831.0,
#   'total_supply': 100000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 93,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 28177,
#   'name': 'Pyth Network',
#   'symbol': 'PYTH',
#   'date_added': '2023-11-20T09:42:13.000Z',
#   'Price': 0.14990414517028217,
#   'volume_24h': 24699021.6523678,
#   'volume_change_24h': -15.8739,
#   'max_supply': 10000000000.0,
#   'circulating_supply': 3624987909.17988,
#   'total_supply': 9999987909.17988,
#   'infinite_supply': 'False',
#   'cmc_rank': 94,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 1966,
#   'name': 'Decentraland',
#   'symbol': 'MANA',
#   'date_added': '2017-09-17T00:00:00.000Z',
#   'Price': 0.27631550853030257,
#   'volume_24h': 47272001.80902769,
#   'volume_change_24h': -28.5759,
#   'max_supply': None,
#   'circulating_supply': 1942255184.1130493,
#   'total_supply': 2193179327.320146,
#   'infinite_supply': 'False',
#   'cmc_rank': 95,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 6538,
#   'name': 'Curve DAO Token',
#   'symbol': 'CRV',
#   'date_added': '2020-08-14T00:00:00.000Z',
#   'Price': 0.4122009238064187,
#   'volume_24h': 89925002.90467788,
#   'volume_change_24h': -19.1533,
#   'max_supply': 3030303030.299,
#   'circulating_supply': 1298735927.0,
#   'total_supply': 2237183021.886897,
#   'infinite_supply': 'False',
#   'cmc_rank': 96,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 14101,
#   'name': 'Ronin',
#   'symbol': 'RON',
#   'date_added': '2021-11-08T17:57:40.000Z',
#   'Price': 0.8573218770499169,
#   'volume_24h': 8058727.58737742,
#   'volume_change_24h': -28.0587,
#   'max_supply': 1000000000.0,
#   'circulating_supply': 619389698.9641546,
#   'total_supply': 1000000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 97,
#   'last_updated': '2025-03-14T19:30:00.000Z'},
#  {'id': 5665,
#   'name': 'Helium',
#   'symbol': 'HNT',
#   'date_added': '2020-06-05T00:00:00.000Z',
#   'Price': 2.919240246687515,
#   'volume_24h': 5592596.80297143,
#   'volume_change_24h': -18.7796,
#   'max_supply': 223000000.0,
#   'circulating_supply': 179443001.1747041,
#   'total_supply': 179443001.1747041,
#   'infinite_supply': 'False',
#   'cmc_rank': 98,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 6783,
#   'name': 'Axie Infinity',
#   'symbol': 'AXS',
#   'date_added': '2020-08-31T00:00:00.000Z',
#   'Price': 3.2455168497532645,
#   'volume_24h': 23403722.67788465,
#   'volume_change_24h': -26.2688,
#   'max_supply': None,
#   'circulating_supply': 159436665.37132165,
#   'total_supply': 270000000.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 99,
#   'last_updated': '2025-03-14T19:31:00.000Z'},
#  {'id': 1437,
#   'name': 'Zcash',
#   'symbol': 'ZEC',
#   'date_added': '2016-10-29T00:00:00.000Z',
#   'Price': 32.289240943791846,
#   'volume_24h': 65749128.91212257,
#   'volume_change_24h': 10.1816,
#   'max_supply': 21000000.0,
#   'circulating_supply': 15886821.0,
#   'total_supply': 15905531.0,
#   'infinite_supply': 'False',
#   'cmc_rank': 100,
#   'last_updated': '2025-03-14T19:30:00.000Z'}]

# %%
builder = pyspark.sql.SparkSession.builder.appName("MyApp") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
df = spark.createDataFrame(transformed_data_list)

# %%
df.show()
# Out:
# +--------------------+--------------------+--------+--------------------+-----+---------------+--------------------+-------------------+------------+------+--------------------+--------------------+-----------------+
# |               Price|  circulating_supply|cmc_rank|          date_added|   id|infinite_supply|        last_updated|         max_supply|        name|symbol|        total_supply|          volume_24h|volume_change_24h|
# +--------------------+--------------------+--------+--------------------+-----+---------------+--------------------+-------------------+------------+------+--------------------+--------------------+-----------------+
# |   84644.78995981331|         1.9836878E7|       1|2010-07-13T00:00:...|    1|          False|2025-03-14T19:30:...|              2.1E7|     Bitcoin|   BTC|         1.9836878E7|2.943607651222203...|          -6.1104|
# |  1935.8155746012596| 1.206141835975569E8|       2|2015-08-07T00:00:...| 1027|           True|2025-03-14T19:30:...|               NULL|    Ethereum|   ETH| 1.206141835975569E8|1.281673136617265...|         -30.3381|
# |  1.0000848462505614| 1.43346765715551E11|       3|2015-02-25T00:00:...|  825|           True|2025-03-14T19:30:...|               NULL| Tether USDt|  USDT|1.445541121588143...|6.152204707600157E10|         -11.0094|
# |   2.357569467548601|     5.8108919817E10|       4|2013-08-04T00:00:...|   52|          False|2025-03-14T19:30:...|             1.0E11|         XRP|   XRP|     9.9986343905E10| 4.474045810298453E9|         -19.5404|
# |    588.495836666123|      1.4247499295E8|       5|2017-07-25T00:00:...| 1839|          False|2025-03-14T19:31:...|               NULL|         BNB|   BNB|      1.4247499295E8|1.5626373860104766E9|         -35.2385|
# |  134.10575152034278|5.0956491433139604E8|       6|2020-04-10T00:00:...| 5426|           True|2025-03-14T19:30:...|               NULL|      Solana|   SOL| 5.961890751958779E8| 3.004777420999797E9|          -0.2194|
# |  0.9998995750402716|5.850196671066599E10|       7|2018-10-08T00:00:...| 3408|          False|2025-03-14T19:31:...|               NULL|        USDC|  USDC|5.850196671066599E10| 9.291946678669954E9|         -23.0389|
# |  0.7391668572996885|3.523063110653998E10|       8|2017-10-01T00:00:...| 2010|          False|2025-03-14T19:31:...|             4.5E10|     Cardano|   ADA| 4.49949384982471E10| 1.011885078054758E9|         -14.2581|
# | 0.17181724251586478|1.484282163837051...|       9|2013-12-15T00:00:...|   74|           True|2025-03-14T19:30:...|               NULL|    Dogecoin|  DOGE|1.484282163837051...|1.0668891084142364E9|         -27.2044|
# |   0.221800436799965|9.502750054423929E10|      10|2017-09-13T00:00:...| 1958|           True|2025-03-14T19:31:...|               NULL|        TRON|   TRX| 9.50275083283081E10| 6.062672043642774E8|           2.0528|
# |   1.520284672253384| 7.071642142047408E9|      11|2025-02-11T07:16:...|35697|          False|2025-03-14T19:31:...|             1.0E11|          Pi|    PI|              1.0E11| 6.774455707869722E8|           4.4042|
# |  14.546585069751284| 6.380999704527867E8|      12|2017-09-20T00:00:...| 1975|          False|2025-03-14T19:30:...|               NULL|   Chainlink|  LINK|               1.0E9| 8.504993093130183E8|         121.6083|
# |    9.80193527668661|       9.239384919E8|      13|2019-05-21T00:00:...| 3957|          False|2025-03-14T19:31:...|               NULL|UNUS SED LEO|   LEO|        9.85239504E8|    2868808.95707105|           5.0288|
# |  0.2752806269672474|3.070788763365079E10|      14|2014-08-05T00:00:...|  512|          False|2025-03-14T19:30:...|    5.0001806812E10|     Stellar|   XLM|5.000178689444301E10| 3.103605301323512E8|         -30.6948|
# | 0.19356464703410678|4.221758082066579E10|      15|2019-09-17T00:00:...| 4642|          False|2025-03-14T19:31:...|             5.0E10|      Hedera|  HBAR|              5.0E10|3.2037747479708636E8|         -20.0587|
# |  19.110334962199826| 4.143611369087372E8|      16|2020-07-13T00:00:...| 5805|          False|2025-03-14T19:31:...|       7.15748719E8|   Avalanche|  AVAX| 4.510306369087372E8| 2.770508806794701E8|         -19.3822|
# |  2.3629865161308445|3.1698450474838877E9|      17|2022-07-12T08:03:...|20947|          False|2025-03-14T19:31:...|             1.0E10|         Sui|   SUI|              1.0E10| 7.866778566825371E8|           0.8411|
# |1.266850341702791...|5.892529861142609E14|      18|2020-08-01T00:00:...| 5994|          False|2025-03-14T19:31:...|5.89552695333683E14|   Shiba Inu|  SHIB|5.895069009161728E14|1.8750345621101367E8|          -0.5935|
# |   2.910626007465746|2.4812401198024983E9|      19|2021-08-26T13:40:...|11419|           True|2025-03-14T19:30:...|               NULL|     Toncoin|   TON| 5.124620289743499E9|1.6045477592046505E8|          14.6306|
# |   92.08231139961003|  7.55584683040892E7|      20|2013-04-28T00:00:...|    2|          False|2025-03-14T19:31:...|              8.4E7|    Litecoin|   LTC|               8.4E7|4.9555983294463754E8|          -4.5312|
# +--------------------+--------------------+--------+--------------------+-----+---------------+--------------------+-------------------+------------+------+--------------------+--------------------+-----------------+
# only showing top 20 rows

# %%
lakehouse = spark.sql("""
    CREATE TABLE IF NOT EXISTS crypto_data
        (id INTEGER,
        name STRING,
        symbol STRING,
        date_added TIMESTAMP,
        Price FLOAT,
        volume_24h FLOAT,
        volume_change_24h FLOAT,
        max_supply FLOAT,
        circulating_supply FLOAT,
        total_supply FLOAT,
        infinite_supply STRING,
        cmc_rank INT,
        last_updated TIMESTAMP) USING delta
""")

# %%
df.write.mode("append").format("delta").saveAsTable("crypto_data")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.write.mode("append").format("delta").saveAsTable("crypto_data")
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/pyspark/sql/readwriter.py:1586, in DataFrameWriter.saveAsTable(self, name, format, mode, partitionBy, **options)
#    1584 if format is not None:
#    1585     self.format(format)
# -> 1586 self._jwrite.saveAsTable(name)
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [DELTA_FAILED_TO_MERGE_FIELDS] Failed to merge fields 'id' and 'id'
